# %% [markdown]
# # 65 Years of St. Louis Rainfall Data
#
# ## Dataset
#
# The following data was requested from NOAA:
# https://www.ncdc.noaa.gov/cdo-web/search
#
# |Field|Value|
# |-----|-----|
# |**Start Date**|1948-08-01|
# |**End Date**|2013-12-23|
# |**Locations**|St. Louis, MO US (CITY:US290021)|
# |**Custom Flag(s)**|Station Name, Geographic Location, Include Data|
# |**Units**|Standard|
# |**Data Types**|HPCP - Precipitation|

# %%
import pandas as pd

df = pd.read_csv('./2261150.csv', parse_dates=[5])
df
# Out:
# /home/g/miniconda3/envs/rwhs/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (2,3,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#            STATION                                  STATION_NAME ELEVATION  \
# 0      COOP:237460                    ST LOUIS EADS BRIDGE MO US       189
# 1      COOP:237460                    ST LOUIS EADS BRIDGE MO US       189
# 2      COOP:237460                    ST LOUIS EADS BRIDGE MO US       189
# 3      COOP:237460                    ST LOUIS EADS BRIDGE MO US       189
# 4      COOP:237460                    ST LOUIS EADS BRIDGE MO US       189
# ...            ...                                           ...       ...
# 79841  COOP:237455  ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US     161.8
# 79842  COOP:237455  ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US     161.8
# ...

# %%
df.groupby('STATION_NAME').agg(['min', 'max']).sort_values(by=[('DATE', 'min'), ('DATE', 'max')], ascending=True)
# Out:
#                                                   STATION               \
#                                                       min          max
# STATION_NAME
# ST LOUIS WSHNGTN UNI MO US                    COOP:237470  COOP:237470
# ST LOUIS EADS BRIDGE MO US                    COOP:237460  COOP:237460
# ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US  COOP:237455  COOP:237455
# JEFFERSON BARRACKS MO US                      COOP:234273  COOP:234273
# ST LOUIS SCIENCE CENTER MO US                 COOP:237452  COOP:237452
#
#                                                             DATE  \
#                                                              min
# STATION_NAME
# ST LOUIS WSHNGTN UNI MO US                   1948-08-01 01:00:00
# ST LOUIS EADS BRIDGE MO US                   1948-08-01 01:00:00
# ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US 1948-08-01 01:00:00
# JEFFERSON BARRACKS MO US                     1959-04-01 01:00:00
# ...

# %%
mm = df.groupby('STATION_NAME').agg(['min', 'max'])
three_sixty_five_days = pd.Timedelta(value=365, unit='days')
rng = (mm['DATE']['max'] - mm['DATE']['min']) / three_sixty_five_days
rng.sort_values(ascending=False)
# Out:
# STATION_NAME
# ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US    65.440525
# JEFFERSON BARRACKS MO US                        54.763584
# ST LOUIS SCIENCE CENTER MO US                   45.506963
# ST LOUIS EADS BRIDGE MO US                      19.928653
# ST LOUIS WSHNGTN UNI MO US                      10.424543
# dtype: float64

# %%
lambert = df.loc[df['STATION_NAME'] == 'ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US']
lambert
# Out:
#            STATION                                  STATION_NAME ELEVATION  \
# 34160  COOP:237455  ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US     175.9
# 34161  COOP:237455  ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US     175.9
# 34162  COOP:237455  ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US     175.9
# 34163  COOP:237455  ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US     175.9
# 34164  COOP:237455  ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US     175.9
# ...            ...                                           ...       ...
# 79841  COOP:237455  ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US     161.8
# 79842  COOP:237455  ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US     161.8
# 79843  COOP:237455  ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US     161.8
# 79844  COOP:237455  ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US     161.8
# 79845  COOP:237455  ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US     161.8
#
# ...

# %%
df = df.loc[df['STATION_NAME'] == 'ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US']
df
# Out:
#            STATION                                  STATION_NAME ELEVATION  \
# 34160  COOP:237455  ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US     175.9
# 34161  COOP:237455  ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US     175.9
# 34162  COOP:237455  ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US     175.9
# 34163  COOP:237455  ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US     175.9
# 34164  COOP:237455  ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US     175.9
# ...            ...                                           ...       ...
# 79841  COOP:237455  ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US     161.8
# 79842  COOP:237455  ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US     161.8
# 79843  COOP:237455  ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US     161.8
# 79844  COOP:237455  ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US     161.8
# 79845  COOP:237455  ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US     161.8
#
# ...

# %%
MISSING_DATA_VALUE = 999.99
df = df.loc[df['HPCP'] != MISSING_DATA_VALUE]
df
# Out:
#            STATION                                  STATION_NAME ELEVATION  \
# 34160  COOP:237455  ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US     175.9
# 34161  COOP:237455  ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US     175.9
# 34162  COOP:237455  ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US     175.9
# 34163  COOP:237455  ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US     175.9
# 34164  COOP:237455  ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US     175.9
# ...            ...                                           ...       ...
# 79841  COOP:237455  ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US     161.8
# 79842  COOP:237455  ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US     161.8
# 79843  COOP:237455  ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US     161.8
# 79844  COOP:237455  ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US     161.8
# 79845  COOP:237455  ST LOUIS LAMBERT INTERNATIONAL AIRPORT MO US     161.8
#
# ...
